# %% [markdown]
# <a href="https://colab.research.google.com/github/rbflakt/DL_project/blob/main/DL_project_YOLO%2BCLIP%2BBLIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##test 데이터 description 작성

# %%
import os

# 경로 설정
label_dir = "/content/drive/MyDrive/gdy/강다영_yolo버전"
description_file_path = "/content/drive/MyDrive/gdy/강다영_yolo버전/captions_only.txt"
output_dir = "/content/drive/MyDrive/gdy/강다영_yolo버전/output"

os.makedirs(output_dir, exist_ok=True)  # output 폴더가 없으면 생성

# description.txt에서 모든 문장 불러오기
with open(description_file_path, "r", encoding="utf-8") as desc_file:
    descriptions = [line.strip() for line in desc_file.readlines() if line.strip()]

desc_index = 0  # description 리스트 인덱스

# 1~14 이미지 라벨 처리
for i in range(1, 15):
    input_file = os.path.join(label_dir, f"image{i}.txt")
    output_file = os.path.join(output_dir, f"output_image{i}.txt")

    with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
        for line in infile:
            parts = line.strip().split()

            if not parts or len(parts) < 5:
                continue  # skip malformed line

            class_id = parts[0]

            # 0번 클래스: description 추가
            if class_id == "0":
                if desc_index < len(descriptions):
                    description = descriptions[desc_index]
                    desc_index += 1
                else:
                    description = ""  # 남은 설명 없으면 빈칸

                outfile.write(f"{' '.join(parts)} {description}\n")

            # 1번 클래스: 그대로 출력
            elif class_id == "1":
                outfile.write(line)

# %% [markdown]
# ##ultralytics 라이브러리 설치

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/235.7 GB disk)

# %% [markdown]
# ##드라이브 연동

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##이미지 증강_hcv

# %%
import cv2
import numpy as np
import os
from PIL import Image
import shutil
from tqdm import tqdm

# ✅ 1. 사용자 입력: 경로 설정
image_folder = "/content/drive/MyDrive/gdy/train_dataset/train_image"       # 🔹 원본 이미지 폴더 (.png)
label_folder = "/content/drive/MyDrive/gdy/train_dataset/train_label"       # 🔹 원본 라벨 폴더 (.txt)
save_image_folder = "/content/drive/MyDrive/gdy/images/train"  # 🔹 저장할 증강 이미지 폴더
save_label_folder = "/content/drive/MyDrive/gdy/labels/train"  # 🔹 저장할 증강 라벨 폴더

os.makedirs(save_image_folder, exist_ok=True)
os.makedirs(save_label_folder, exist_ok=True)

# ✅ 2. HSV 증강 함수
def apply_hsv_augmentation(img, h_shift=0.0, s_shift=0.0, v_shift=0.0):
    hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV).astype(np.float32)
    h, s, v = cv2.split(hsv_img)
    h = (h + h_shift * 179) % 179
    s = np.clip(s + s_shift * 255, 0, 255)
    v = np.clip(v + v_shift * 255, 0, 255)
    hsv_aug = cv2.merge([h, s, v]).astype(np.uint8)
    return cv2.cvtColor(hsv_aug, cv2.COLOR_HSV2RGB)

# ✅ 3. 독립적 증강 파라미터 설정
hue_values = [-0.5, -0.25, 0.0, 0.25, 0.5]
sat_values = [-1.0, -0.5, 0.0, 0.5, 1.0]
val_values = [-0.8, -0.4, 0.0, 0.4, 0.8]

# ✅ 4. 이미지+라벨 반복 증강 및 저장
image_files = [f for f in os.listdir(image_folder) if f.endswith(".png")]

for image_name in tqdm(image_files, desc="Augmenting images"):
    base_name = os.path.splitext(image_name)[0]
    image_path = os.path.join(image_folder, image_name)
    label_path = os.path.join(label_folder, base_name + ".txt")

    if not os.path.exists(label_path):
        print(f"⚠️ 라벨 파일 없음: {label_path}")
        continue

    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 🔹 색조만 증강 (5개)
    for i, h in enumerate(hue_values):
        aug = apply_hsv_augmentation(img, h_shift=h)
        aug_name = f"{base_name}_h{i}.jpg"
        Image.fromarray(aug).save(os.path.join(save_image_folder, aug_name))
        shutil.copy(label_path, os.path.join(save_label_folder, f"{base_name}_h{i}.txt"))

    # 🔹 채도만 증강 (5개)
    for i, s in enumerate(sat_values):
        aug = apply_hsv_augmentation(img, s_shift=s)
        aug_name = f"{base_name}_s{i}.jpg"
        Image.fromarray(aug).save(os.path.join(save_image_folder, aug_name))
        shutil.copy(label_path, os.path.join(save_label_folder, f"{base_name}_s{i}.txt"))

    # 🔹 밝기만 증강 (5개)
    for i, v in enumerate(val_values):
        aug = apply_hsv_augmentation(img, v_shift=v)
        aug_name = f"{base_name}_v{i}.jpg"
        Image.fromarray(aug).save(os.path.join(save_image_folder, aug_name))
        shutil.copy(label_path, os.path.join(save_label_folder, f"{base_name}_v{i}.txt"))

print("✅ 모든 이미지 및 라벨 증강 완료 (1장당 15장 생성)")
# Out:
# Augmenting images: 100%|██████████| 90/90 [02:20<00:00,  1.56s/it]
# ✅ 모든 이미지 및 라벨 증강 완료 (1장당 15장 생성)

# %% [markdown]
# ##이미지 증강_geo

# %%
import cv2
import numpy as np
import os
from PIL import Image
import shutil
from tqdm import tqdm

# 📌 경로 설정 (사용자 수정 부분)
image_folder = "/content/drive/MyDrive/gdy/train_dataset/train_image"
label_folder = "/content/drive/MyDrive/gdy/train_dataset/train_label"
save_image_folder = "/content/drive/MyDrive/gdy/images/train"
save_label_folder = "/content/drive/MyDrive/gdy/labels/train"

os.makedirs(save_image_folder, exist_ok=True)
os.makedirs(save_label_folder, exist_ok=True)

# ✅ 증강 타입별 접두어 매핑
type_map = {
    "rotate": "ro",
    "translate": "tr",
    "scale": "sc",
    "shear": "sh",
    "perspective": "pe"
}

# ✅ 기하학적 변환 함수
def apply_geometric_augmentation(img, aug_type, value):
    height, width = img.shape[:2]
    center = (width / 2, height / 2)

    if aug_type == "rotate":
        matrix = cv2.getRotationMatrix2D(center, value, 1.0)
        return cv2.warpAffine(img, matrix, (width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
    elif aug_type == "translate":
        tx = int(value * width)
        ty = int(value * height)
        matrix = np.float32([[1, 0, tx], [0, 1, ty]])
        return cv2.warpAffine(img, matrix, (width, height), borderMode=cv2.BORDER_REFLECT)
    elif aug_type == "scale":
        scale_factor = 1 + value
        matrix = cv2.getRotationMatrix2D(center, 0, scale_factor)
        return cv2.warpAffine(img, matrix, (width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
    elif aug_type == "shear":
        shear_factor = np.tan(np.radians(value))
        matrix = np.array([[1, shear_factor, 0], [0, 1, 0]], dtype=np.float32)
        return cv2.warpAffine(img, matrix, (width, height), borderMode=cv2.BORDER_REFLECT)
    elif aug_type == "perspective":
        dx = int(value * width)
        dy = int(value * height)
        pts1 = np.float32([[0, 0], [width, 0], [0, height], [width, height]])
        pts2 = np.float32([[0 + dx, 0 + dy], [width - dx, 0 + dy],
                           [0 + dx, height - dy], [width - dx, height - dy]])
        matrix = cv2.getPerspectiveTransform(pts1, pts2)
        return cv2.warpPerspective(img, matrix, (width, height), borderMode=cv2.BORDER_REFLECT)
    else:
        raise ValueError("Unknown augmentation type")

# ✅ 변환 설정
augmentation_params = {
    "rotate": [-180, -90, 0, 90, 180],
    "translate": [-0.5, -0.25, 0, 0.25, 0.5],
    "scale": [-0.5, -0.25, 0, 0.25, 0.5],
    "shear": [-10, -5, 0, 5, 10],
    "perspective": [-0.001, -0.0005, 0, 0.0005, 0.001]
}

# ✅ 이미지 목록
image_files = sorted([f for f in os.listdir(image_folder) if f.endswith(".png")])

# ✅ 증강 실행
for idx, image_name in enumerate(tqdm(image_files, desc="Geometric augmentation")):
    base_number = f"{idx:04d}"  # ← 수정됨: 0부터 시작
    image_path = os.path.join(image_folder, image_name)
    label_path = os.path.join(label_folder, os.path.splitext(image_name)[0] + ".txt")

    if not os.path.exists(label_path):
        print(f"⚠️ 라벨 없음: {label_path}")
        continue

    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    for aug_type, values in augmentation_params.items():
        prefix = type_map[aug_type]
        for i, val in enumerate(values):
            aug_img = apply_geometric_augmentation(img, aug_type, val)
            filename = f"img_{base_number}_{prefix}{i}"
            img_path = os.path.join(save_image_folder, filename + ".jpg")
            lbl_path = os.path.join(save_label_folder, filename + ".txt")

            Image.fromarray(aug_img).save(img_path)
            shutil.copy(label_path, lbl_path)

print("✅ 모든 증강 이미지 및 라벨 파일 저장 완료 (파일명 숫자 0부터 시작)")
# Out:
# Geometric augmentation: 100%|██████████| 90/90 [02:59<00:00,  1.99s/it]
# ✅ 모든 증강 이미지 및 라벨 파일 저장 완료 (파일명 숫자 0부터 시작)

# %% [markdown]
# ##yaml 생성

# %%
project_path = '/content/drive/MyDrive'

# data.yaml 생성
data_yaml = f"""
path: /content/drive/MyDrive/gdy
train: images/train
val: images/val
test: images/test

nc: 1
names: ["icon"]

"""

with open(f"{project_path}/data.yaml", "w") as f:
    f.write(data_yaml)

# %% [markdown]
# ##yolo 학습

# %%
# !pip install ultralytics
# !yolo task=detect mode=val \
      model="/content/drive/MyDrive/gdy/best.pt" \
      data="/content/drive/MyDrive/data.yaml" \
      split=test
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.158)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 131.2±144.0 MB/s, size: 1136.3 KB)
# val: Scanning /content/drive/MyDrive/gdy/labels/test.cache... 118 images, 7 backgrounds, 99 corrupt: 100% 125/125 [00:00<?, ?it/s]
# val: /content/drive/MyDrive/gdy/images/test/Screenshot 2025-06-09 at 4.55.53 PM.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/Screenshot 2025-06-10 at 1.40.42 PM.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/Screenshot 2025-06-10 at 1.41.30 PM.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/Screenshot 2025-06-10 at 1.45.22 PM.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030105.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030125.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030158.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030259.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030425.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030708.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a030937.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a031041.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a031123.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a031451.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a031510.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/a115252.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aaa1.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aaa2.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aaa3.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aaaa.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/ak3.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/akk4.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/akk5.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/akk6.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aksyd2.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/aksyd4.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/cgv.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image1 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image1.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image10 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image11 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image11.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image12 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image12 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image12.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image13 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image13 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image13.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image14.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image15.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image2 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image2.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image3 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image3 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image3.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image4 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image4 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image4.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image5.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image6 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image6.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image7 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image7 (2).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image7.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image8 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image8.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image9 (1).png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/image9.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/kt.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y050302.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y050502.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y050530.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y050549.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y050645.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y154630.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y154706.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y154834.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y155251.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y155325.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y155407.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y155443.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y160130.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/y160356.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/z2.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/z3.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/z4.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/당근.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/도쿄디즈니랜드.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/링크드인.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/메가박스.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/소니-아이보.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 195700.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 195717.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 200021.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 200547.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 200750.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 200847.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 200909.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 201100.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 201434.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/스크린샷 2025-06-08 203539.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/실시간지하철노선도.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/안경-라운즈.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/에버랜드.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/울프람알파.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/유튜브.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/이케아.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/정부24.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: /content/drive/MyDrive/gdy/images/test/코드잇.png: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.84it/s]
#                    all         26        346      0.191      0.199     0.0914     0.0296
# Speed: 1.8ms preprocess, 13.3ms inference, 0.0ms loss, 13.6ms postprocess per image
# Results saved to runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ##BLIP+CLIP

# %%
import json
import os
from PIL import Image
from collections import defaultdict
from torchvision import transforms

import torch
from transformers import CLIPProcessor, CLIPModel
from transformers import BlipProcessor, BlipForConditionalGeneration

# 경로 설정
json_path = "/content/drive/MyDrive/gdy/instances_converted_fin.json"
image_folder = "/content/drive/MyDrive/gdy/images/test"

# 장비 설정
device = "cuda" if torch.cuda.is_available() else "cpu"

# CLIP 로드
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# BLIP 로드
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(device)
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")

# CLIP 후보 설명어
candidate_texts = [
    "WhatsApp logo",
    "Instagram icon",
    "Phone symbol",
    "Chat application logo",
    "Social media icon",
    "Facebook logo",
    "Twitter logo",
    "LinkedIn logo",
    "YouTube logo",
    "Adobe Premiere logo",
    "Adobe Illustrator logo",
    "Adobe Photoshop logo",
    "American flag",
    "British flag",
    "German flag",
    "Chinese flag",
    "Japanese flag"
]

# confidence 기준값
CONFIDENCE_THRESHOLD = 0.85

# COCO json 불러오기
with open(json_path, "r") as f:
    coco = json.load(f)

image_id_to_filename = {img['id']: img['file_name'] for img in coco['images']}

annotations_by_image = defaultdict(list)
for ann in coco['annotations']:
    image_id = ann['image_id']
    x, y, w, h = ann['bbox']
    category_id = ann['category_id']
    annotations_by_image[image_id].append({
        "bbox": [x, y, x + w, y + h],
        "category_id": category_id
    })

# CLIP 예측 함수
def generate_clip_caption(crop_img):
    inputs = clip_processor(text=candidate_texts, images=crop_img, return_tensors="pt", padding=True).to(device)
    outputs = clip_model(**inputs)
    probs = outputs.logits_per_image.softmax(dim=1)
    best_idx = probs.argmax().item()
    caption = candidate_texts[best_idx]
    confidence = probs[0][best_idx].item()
    return caption, confidence

# BLIP 캡션 생성
def generate_blip_caption(crop_img):
    inputs = blip_processor(images=crop_img, return_tensors="pt").to(device)
    out_ids = blip_model.generate(
        **inputs,
        max_length=20,
        num_beams=5,
        repetition_penalty=2.0,
        length_penalty=1.0,
        early_stopping=True
    )
    caption = blip_processor.decode(out_ids[0], skip_special_tokens=True)
    return caption

# 이미지 순회하며 처리
category_id_to_name = {cat["id"]: cat["name"] for cat in coco["categories"]}

collected_captions = []

for image_id, bbox_list in annotations_by_image.items():
    filename = image_id_to_filename[image_id]
    image_path = os.path.join(image_folder, filename)

    if not os.path.exists(image_path):
        print(f"[경고] 이미지 없음: {filename}")
        continue

    img = Image.open(image_path).convert("RGB")
    print(f"\n===== {filename} =====")
    for idx, box_data in enumerate(bbox_list):
        x1, y1, x2, y2 = map(int, box_data['bbox'])
        category_id = box_data['category_id']
        category_name = category_id_to_name.get(category_id, "")

        # 아이콘이 아니면 캡션 건너뜀
        if category_name != "icon":
            print(f"[{idx+1}] 카테고리 '{category_name}' → 캡션 생략")
            continue
        ###데이터 증강
        crop = img.crop((x1, y1, x2, y2))
        augment = transforms.Compose([
           transforms.RandomHorizontalFlip(p=0.5),
           transforms.ColorJitter(brightness=0.2, contrast=0.2),
           transforms.RandomRotation(degrees=15)
        ])

        # crop → Tensor → 증강 → PIL 다시 변환
        crop_tensor = transforms.ToTensor()(crop)
        augmented_tensor = augment(crop_tensor)
        augmented_crop = transforms.ToPILImage()(augmented_tensor)

        clip_caption, clip_conf = generate_clip_caption(crop)

        if clip_conf < CONFIDENCE_THRESHOLD:
            caption = generate_blip_caption(crop)
            source = "BLIP"
        else:
            caption = clip_caption
            source = f"CLIP ({clip_conf:.2f})"

        print(f"[{idx+1}] Cat: {category_name} | Box: ({x1}, {y1}, {x2}, {y2})")
        print(f" → Caption: {caption} [{source}]")
        collected_captions.append(caption)

save_path = "/content/drive/MyDrive/gdy/captions_only_fin.txt"
with open(save_path, "w", encoding="utf-8") as f:
    for cap in collected_captions:
        f.write(cap + "\n")

print(f"\n✅ 캡션만 저장 완료: {save_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [16] Cat: icon | Box: (1924, 334, 2092, 489)
#  → Caption: Twitter logo [CLIP (0.98)]
# [17] Cat: icon | Box: (2236, 334, 2409, 502)
#  → Caption: Instagram icon [CLIP (0.90)]
# [18] Cat: icon | Box: (2447, 334, 2609, 497)
#  → Caption: a blue circle with an arrow in the middle [BLIP]
# [19] Cat: icon | Box: (2640, 333, 2816, 479)
#  → Caption: a blue airplane icon on a white background [BLIP]
# [20] Cat: icon | Box: (2640, 517, 2806, 687)
#  → Caption: Chat application logo [CLIP (0.92)]
# [21] Cat: icon | Box: (2435, 517, 2606, 687)
#  → Caption: LinkedIn logo [CLIP (1.00)]
# [22] Cat: icon | Box: (2229, 527, 2400, 687)
#  → Caption: WhatsApp logo [CLIP (0.97)]
# [23] Cat: icon | Box: (501, 514, 672, 690)
#  → Caption: Chinese flag [CLIP (0.96)]
# [24] Cat: icon | Box: (304, 514, 464, 698)
#  → Caption: the flag of spain [BLIP]
# [25] Cat: icon | Box: (88, 511, 274, 701)
#  → Caption: German flag [CLIP (1.00)]
# [26] Cat: icon | Box: (104, 818, 269, 984)
#  → Caption: Adobe Photoshop logo [CLIP (0.92)]
# [27] Cat: icon | Box: (301, 821, 472, 989)
#  → Caption: Adobe Illustrator logo [CLIP (0.90)]
# [28] Cat: icon | Box: (504, 818, 666, 989)
#  → Caption: a purple circle with the word ae [BLIP]
# [29] Cat: icon | Box: (101, 1005, 269, 1184)
#  → Caption: Adobe Premiere logo [CLIP (0.97)]
# [30] Cat: icon | Box: (304, 1010, 469, 1170)
#  → Caption: the id logo [BLIP]
# [31] Cat: icon | Box: (504, 1008, 672, 1170)
#  → Caption: the lr logo on a white background [BLIP]
# [32] Cat: icon | Box: (808, 824, 997, 994)
#  → Caption: a yellow envelope with an email icon on it [BLIP]
# [33] Cat: icon | Box: (1024, 826, 1184, 994)
#  → Caption: Chat application logo [CLIP (0.99)]
# [34] Cat: icon | Box: (1219, 824, 1376, 994)
#  → Caption: the green phone icon with a white background [BLIP]
# [35] Cat: icon | Box: (808, 1010, 978, 1173)
#  → Caption: the camera icon [BLIP]
# [36] Cat: icon | Box: (1016, 1008, 1176, 1178)
#  → Caption: the app icon for ios [BLIP]
# [37] Cat: icon | Box: (1219, 1010, 1387, 1181)
#  → Caption: a cloud with the letter c on it [BLIP]
# [38] Cat: icon | Box: (1523, 818, 1701, 997)
#  → Caption: an elephant ' s head with a white background [BLIP]
# [39] Cat: icon | Box: (1728, 821, 1899, 1005)
#  → Caption: a green and yellow bird with a pink beak [BLIP]
# [40] Cat: icon | Box: (1928, 818, 2096, 986)
#  → Caption: a blue hippoy icon on a white background [BLIP]
# [41] Cat: icon | Box: (1525, 1008, 1699, 1181)
#  → Caption: a turtle with green leaves on its back [BLIP]
# [42] Cat: icon | Box: (1731, 1010, 1896, 1176)
#  → Caption: a green parrot sitting on a branch [BLIP]
# [43] Cat: icon | Box: (1928, 1005, 2101, 1184)
#  → Caption: a panda face on a white background [BLIP]
# [44] Cat: icon | Box: (2229, 821, 2405, 981)
#  → Caption: a pink triangle on a white background [BLIP]
# [45] Cat: icon | Box: (2429, 829, 2627, 989)
#  → Caption: the live button on a white background [BLIP]
# [46] Cat: icon | Box: (2643, 829, 2819, 986)
#  → Caption: the play button on a white background [BLIP]
# [47] Cat: icon | Box: (2232, 1005, 2416, 1176)
#  → Caption: a pink ribbon on a white background [BLIP]
# [48] Cat: icon | Box: (2427, 1000, 2622, 1176)
#  → Caption: a pink heart icon on a white background [BLIP]
# [49] Cat: icon | Box: (2643, 1002, 2806, 1173)
#  → Caption: a button with an arrow pointing towards it [BLIP]
# [50] Cat: icon | Box: (512, 1306, 677, 1456)
#  → Caption: a magnit on a white background [BLIP]
# [51] Cat: icon | Box: (98, 1320, 266, 1418)
#  → Caption: a blue cloud on a white background [BLIP]
# [52] Cat: icon | Box: (314, 1306, 450, 1416)
#  → Caption: a blue circle with a white dot on it [BLIP]
# [53] Cat: icon | Box: (824, 1309, 978, 1456)
#  → Caption: a green check mark on a white background [BLIP]
# [54] Cat: icon | Box: (1024, 1312, 1171, 1456)
#  → Caption: a clipboard with a check mark on it [BLIP]
# [55] Cat: icon | Box: (1213, 1301, 1395, 1456)
#  → Caption: two green and red circles with a check mark in the middle [BLIP]
# [56] Cat: icon | Box: (1531, 1306, 1696, 1456)
#  → Caption: a purple flower on a white background [BLIP]
# [57] Cat: icon | Box: (1720, 1309, 1893, 1456)
#  → Caption: a purple and green leaf on a white background [BLIP]
# [58] Cat: icon | Box: (1928, 1304, 2096, 1456)
#  → Caption: a purple flower on a white background [BLIP]
# [59] Cat: icon | Box: (2232, 1309, 2411, 1456)
#  → Caption: Facebook logo [CLIP (0.89)]
# [60] Cat: icon | Box: (2437, 1309, 2608, 1456)
#  → Caption: YouTube logo [CLIP (0.99)]
# [61] Cat: icon | Box: (2635, 1306, 2827, 1456)
#  → Caption: a purple circle with the word ins on it [BLIP]
# [62] Cat: icon | Box: (2365, 34, 2429, 85)
#  → Caption: the flag of the united states [BLIP]
# [63] Cat: icon | Box: (2672, 26, 2720, 90)
#  → Caption: a white cloud icon on a black background [BLIP]
# [64] Cat: icon | Box: (2742, 13, 2830, 103)
#  → Caption: a brown and white logo with the letter s f [BLIP]
# [65] Cat: icon | Box: (2566, 143, 2622, 210)
#  → Caption: a black and white logo with the words [BLIP]
# [66] Cat: icon | Box: (1208, 517, 1392, 693)
#  → Caption: LinkedIn logo [CLIP (0.99)]
# [67] Cat: icon | Box: (2448, 146, 2506, 207)
#  → Caption: a black and white image of a mag glass [BLIP]
#
# ===== image13 (1).png =====
# [1] Cat: icon | Box: (646, 1029, 687, 1075)
#  → Caption: a black and white logo with the letter q [BLIP]
# [2] 카테고리 '' → 캡션 생략
# [3] 카테고리 '' → 캡션 생략
# [4] Cat: icon | Box: (128, 288, 159, 331)
#  → Caption: an icon of a bell on a black background [BLIP]
# [5] Cat: icon | Box: (117, 188, 164, 229)
#  → Caption: a black and white logo with the letter q on it [BLIP]
# [6] Cat: icon | Box: (32, 9, 78, 51)
#  → Caption: an image of a purple background with white lines [BLIP]
# [7] Cat: icon | Box: (106, 6, 161, 52)
#  → Caption: a black and white logo with the letter d on it [BLIP]
# [8] Cat: icon | Box: (121, 86, 162, 127)
#  → Caption: a small house in the middle of nowhere [BLIP]
# [9] Cat: icon | Box: (610, 145, 642, 178)
#  → Caption: a black and white logo with the letter g [BLIP]
# [10] Cat: icon | Box: (120, 392, 164, 434)
#  → Caption: a black and white logo with the letter f [BLIP]
# [11] Cat: icon | Box: (120, 496, 165, 537)
#  → Caption: a black background with three white dots [BLIP]
# [12] Cat: icon | Box: (24, 631, 61, 674)
#  → Caption: a white cross on a purple background [BLIP]
# [13] Cat: icon | Box: (294, 84, 319, 111)
#  → Caption: a white check mark on a black background [BLIP]
# [14] Cat: icon | Box: (349, 79, 394, 120)
#  → Caption: a black and white icon with three arrows [BLIP]
# [15] Cat: icon | Box: (403, 79, 450, 119)
#  → Caption: a black and white image of a pen on a dark background [BLIP]
# [16] Cat: icon | Box: (221, 154, 263, 191)
#  → Caption: a black and white logo with the letter e on it [BLIP]
# [17] Cat: icon | Box: (220, 199, 262, 232)
#  → Caption: a black and white logo with the letter g on it [BLIP]
# [18] Cat: icon | Box: (222, 237, 264, 285)
#  → Caption: a white triangle on a black background [BLIP]
# [19] Cat: icon | Box: (226, 318, 254, 348)
#  → Caption: a white triangle on a black background [BLIP]
# [20] Cat: icon | Box: (220, 357, 257, 398)
#  → Caption: a black and white hash icon [BLIP]
# [21] Cat: icon | Box: (220, 403, 261, 432)
#  → Caption: the hash icon on a black background [BLIP]
# [22] Cat: icon | Box: (220, 444, 261, 475)
#  → Caption: a purple background with an icon of a lock [BLIP]
# [23] Cat: icon | Box: (224, 484, 254, 518)
#  → Caption: a lock icon on a black background [BLIP]
# [24] Cat: icon | Box: (221, 528, 258, 562)
#  → Caption: a white hash icon on a black background [BLIP]
# [25] Cat: icon | Box: (224, 570, 255, 600)
#  → Caption: the hash logo on a black background [BLIP]
# [26] Cat: icon | Box: (224, 616, 256, 641)
#  → Caption: a white cross on a black background [BLIP]
# [27] Cat: icon | Box: (227, 672, 252, 700)
#  → Caption: a black background with a white arrow icon [BLIP]
# [28] Cat: icon | Box: (230, 730, 254, 751)
#  → Caption: a white triangle on a black background [BLIP]
# [29] Cat: icon | Box: (221, 762, 260, 803)
#  → Caption: the face of a person with different colored eyes [BLIP]
# [30] Cat: icon | Box: (227, 813, 252, 837)
#  → Caption: a white cross on a black background [BLIP]
# [31] Cat: icon | Box: (102, 947, 181, 1027)
#  → Caption: a black background with a white cross in the center [BLIP]
# [32] Cat: icon | Box: (110, 1030, 175, 1103)
#  → Caption: a black background with a blue and green logo [BLIP]
# [33] Cat: icon | Box: (24, 1132, 72, 1182)
#  → Caption: a black background with the letter q and an orange crescent [BLIP]
# [34] Cat: icon | Box: (451, 10, 489, 47)
#  → Caption: a white arrow on a purple background [BLIP]
# [35] Cat: icon | Box: (499, 10, 536, 48)
#  → Caption: a white arrow on a purple background [BLIP]
# [36] Cat: icon | Box: (547, 9, 587, 49)
#  → Caption: a clock icon on a purple background [BLIP]
# [37] Cat: icon | Box: (493, 81, 523, 115)
#  → Caption: a black and white image of a padlock [BLIP]
# [38] Cat: icon | Box: (495, 148, 531, 181)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [39] Cat: icon | Box: (765, 148, 795, 177)
#  → Caption: a black background with a white logo on it [BLIP]
# [40] Cat: icon | Box: (860, 142, 902, 180)
#  → Caption: a white cross on a black background [BLIP]
# [41] Cat: icon | Box: (1270, 11, 1302, 48)
#  → Caption: a purple background with a white outline of a speech bubble [BLIP]
# [42] Cat: icon | Box: (1662, 10, 1704, 52)
#  → Caption: a white circle with a question mark on it [BLIP]
# [43] Cat: icon | Box: (1731, 12, 1765, 50)
#  → Caption: an image of a purple background with white lines [BLIP]
# [44] Cat: icon | Box: (1798, 8, 1836, 48)
#  → Caption: a black and white logo with the letter o on it [BLIP]
# [45] Cat: icon | Box: (1873, 11, 1898, 43)
#  → Caption: the x logo on a purple background [BLIP]
# [46] Cat: icon | Box: (1760, 76, 1800, 115)
#  → Caption: Phone symbol [CLIP (0.93)]
# [47] Cat: icon | Box: (1815, 85, 1832, 105)
#  → Caption: a black background with a white check mark [BLIP]
# [48] Cat: icon | Box: (1860, 74, 1884, 119)
#  → Caption: a black background with white circles on it [BLIP]
# [49] Cat: icon | Box: (566, 257, 601, 293)
#  → Caption: a black background with the number 3 on it [BLIP]
# [50] Cat: icon | Box: (640, 259, 673, 292)
#  → Caption: a black square with the number one on it [BLIP]
# [51] Cat: icon | Box: (710, 259, 741, 291)
#  → Caption: a square icon with the number 2 on it [BLIP]
# [52] Cat: icon | Box: (779, 260, 814, 293)
#  → Caption: a black and white image of a smiley face [BLIP]
# [53] Cat: icon | Box: (484, 356, 558, 433)
#  → Caption: a black background with a green icon in the center [BLIP]
# [54] Cat: icon | Box: (638, 701, 666, 729)
#  → Caption: a white triangle on a black background [BLIP]
# [55] Cat: icon | Box: (509, 917, 541, 955)
#  → Caption: a black and white logo with the letter b [BLIP]
# [56] Cat: icon | Box: (556, 919, 589, 954)
#  → Caption: a black and white logo with the letter t on it [BLIP]
# [57] Cat: icon | Box: (603, 919, 638, 956)
#  → Caption: a black and white logo with the letter e [BLIP]
# [58] Cat: icon | Box: (645, 922, 663, 954)
#  → Caption: a black and white image of a cross [BLIP]
# [59] Cat: icon | Box: (668, 922, 699, 954)
#  → Caption: a black background with a white cloud in the middle [BLIP]
# [60] Cat: icon | Box: (710, 919, 749, 958)
#  → Caption: an image of a black background with white text [BLIP]
# [61] Cat: icon | Box: (757, 920, 801, 956)
#  → Caption: an image of a black background with white text [BLIP]
# [62] Cat: icon | Box: (801, 920, 820, 961)
#  → Caption: an image of a black and white background [BLIP]
# [63] Cat: icon | Box: (820, 920, 857, 959)
#  → Caption: a black and white logo with the letter e on it [BLIP]
# [64] Cat: icon | Box: (866, 915, 911, 963)
#  → Caption: a black and white logo [BLIP]
# [65] Cat: icon | Box: (920, 918, 956, 960)
#  → Caption: a black and white image of a computer screen [BLIP]
# [66] Cat: icon | Box: (512, 985, 538, 1010)
#  → Caption: a lock icon on a black background [BLIP]
# [67] Cat: icon | Box: (507, 1033, 545, 1078)
#  → Caption: a white cross on a black background [BLIP]
# [68] Cat: icon | Box: (548, 1036, 592, 1076)
#  → Caption: a logo with the letter a on it [BLIP]
# [69] Cat: icon | Box: (597, 1038, 639, 1073)
#  → Caption: a black and white photo of a smiley face [BLIP]
# [70] Cat: icon | Box: (692, 1033, 711, 1075)
#  → Caption: a black square button with the number 1 on it [BLIP]
# [71] Cat: icon | Box: (715, 1034, 752, 1072)
#  → Caption: a black and white image of a book [BLIP]
# [72] Cat: icon | Box: (767, 1037, 797, 1070)
#  → Caption: a black and white image of a microphone [BLIP]
# [73] Cat: icon | Box: (806, 1035, 826, 1075)
#  → Caption: an image of a black background with a white stripe [BLIP]
# [74] Cat: icon | Box: (836, 1038, 869, 1073)
#  → Caption: a black and white image of a square icon [BLIP]
# [75] Cat: icon | Box: (1787, 1035, 1819, 1076)
#  → Caption: a black background with a white arrow symbol [BLIP]
# [76] Cat: icon | Box: (1823, 1034, 1836, 1078)
#  → Caption: an image of a black and white background [BLIP]
# [77] Cat: icon | Box: (1841, 1036, 1865, 1073)
#  → Caption: an image of a black background with white text [BLIP]
# [78] Cat: icon | Box: (1742, 1144, 1777, 1183)
#  → Caption: a black and white logo on a black background [BLIP]
# [79] Cat: icon | Box: (1703, 1144, 1741, 1182)
#  → Caption: a black and white logo with the letter x on it [BLIP]
# [80] Cat: icon | Box: (1666, 1143, 1704, 1180)
#  → Caption: a black background with a white wi logo [BLIP]
# [81] Cat: icon | Box: (1617, 1145, 1648, 1183)
#  → Caption: a black and white logo on a black background [BLIP]
# [82] Cat: icon | Box: (1555, 1141, 1588, 1184)
#  → Caption: a black and white logo [BLIP]
# [83] Cat: icon | Box: (1507, 1148, 1545, 1183)
#  → Caption: a black background with a blue and green shield icon [BLIP]
# [84] Cat: icon | Box: (1458, 1147, 1495, 1180)
#  → Caption: a black and white photo of a house [BLIP]
# [85] Cat: icon | Box: (444, 1135, 495, 1188)
#  → Caption: the windows 10 logo [BLIP]
# [86] Cat: icon | Box: (517, 1147, 552, 1181)
#  → Caption: a black background with a white circle on it [BLIP]
# [87] Cat: icon | Box: (848, 1140, 895, 1185)
#  → Caption: a yellow square with the word talk on it [BLIP]
# [88] Cat: icon | Box: (910, 1142, 962, 1188)
#  → Caption: a green spot on a black background [BLIP]
# [89] Cat: icon | Box: (976, 1137, 1032, 1187)
#  → Caption: a black and white image of a book on a black background [BLIP]
# [90] Cat: icon | Box: (1045, 1136, 1097, 1185)
#  → Caption: a black and white logo with the number 40 on it [BLIP]
# [91] Cat: icon | Box: (1109, 1136, 1163, 1193)
#  → Caption: an image of a square in yellow and red [BLIP]
# [92] Cat: icon | Box: (1175, 1137, 1231, 1190)
#  → Caption: a folder icon on a black background [BLIP]
# [93] Cat: icon | Box: (1241, 1135, 1298, 1190)
#  → Caption: the google chrome logo [BLIP]
# [94] Cat: icon | Box: (1307, 1137, 1362, 1184)
#  → Caption: a black background with a white circle and colorful circles [BLIP]
# [95] Cat: icon | Box: (1251, 205, 1279, 236)
#  → Caption: an image of a black background with a white arrow in the middle [BLIP]
#
# ===== image12 (2).png =====
# [1] Cat: icon | Box: (36, 995, 250, 1180)
#  → Caption: an icon of a magnit with a magnit [BLIP]
# [2] Cat: icon | Box: (311, 990, 502, 1162)
#  → Caption: a black and white image of a camera [BLIP]
# [3] Cat: icon | Box: (585, 982, 775, 1165)
#  → Caption: an image of a robot on a white background [BLIP]
# [4] Cat: icon | Box: (567, 727, 775, 902)
#  → Caption: two speech bubbles on a white background [BLIP]
# [5] Cat: icon | Box: (324, 732, 505, 912)
#  → Caption: a black and white logo with the letter e - o [BLIP]
# [6] Cat: icon | Box: (33, 729, 250, 905)
#  → Caption: an image of a white background with grey lines [BLIP]
# [7] Cat: icon | Box: (585, 471, 781, 657)
#  → Caption: a black and white image of a skull head [BLIP]
# [8] Cat: icon | Box: (291, 469, 549, 647)
#  → Caption: an image of a computer screen with three different icons on it [BLIP]
# [9] Cat: icon | Box: (38, 461, 242, 657)
#  → Caption: the adobe logo is shown on a white background [BLIP]
# [10] 카테고리 '' → 캡션 생략
# [11] Cat: icon | Box: (311, 1260, 507, 1405)
#  → Caption: an image of a computer with the letter a on it [BLIP]
# [12] Cat: icon | Box: (582, 1253, 783, 1420)
#  → Caption: an image of a hand with a clock on it [BLIP]
# [13] Cat: icon | Box: (33, 1260, 247, 1430)
#  → Caption: an image of a computer screen with icons on it [BLIP]
#
# ===== image7 (1).png =====
# [1] Cat: icon | Box: (60, 129, 85, 172)
#  → Caption: an image of a black and white background [BLIP]
# [2] Cat: icon | Box: (6, 11, 52, 50)
#  → Caption: a black circle with a white check mark on it [BLIP]
# [3] Cat: icon | Box: (62, 12, 104, 56)
#  → Caption: a green cup with a leaf on it [BLIP]
# [4] Cat: icon | Box: (378, 13, 397, 46)
#  → Caption: a black and white logo with the letter x [BLIP]
# [5] Cat: icon | Box: (417, 13, 458, 51)
#  → Caption: a white cross on a black background [BLIP]
# [6] Cat: icon | Box: (17, 74, 49, 116)
#  → Caption: a white arrow on a black background [BLIP]
# [7] Cat: icon | Box: (69, 76, 105, 119)
#  → Caption: a black and white image of an arrow [BLIP]
# [8] Cat: icon | Box: (117, 76, 159, 119)
#  → Caption: a black and white logo with the letter c [BLIP]
# [9] Cat: icon | Box: (182, 65, 228, 124)
#  → Caption: a black and white logo with the letter c on it [BLIP]
# [10] Cat: icon | Box: (14, 129, 62, 168)
#  → Caption: a black background with white squares on it [BLIP]
# [11] Cat: icon | Box: (88, 125, 122, 168)
#  → Caption: a black background with the google logo [BLIP]
# [12] Cat: icon | Box: (187, 133, 228, 168)
#  → Caption: YouTube logo [CLIP (0.97)]
# [13] Cat: icon | Box: (319, 126, 360, 174)
#  → Caption: a green square icon with the letter n on it [BLIP]
# [14] Cat: icon | Box: (420, 130, 465, 174)
#  → Caption: a black background with the google logo on it [BLIP]
# [15] Cat: icon | Box: (521, 130, 564, 174)
#  → Caption: a black background with a white circle in the middle [BLIP]
# [16] Cat: icon | Box: (294, 407, 358, 477)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [17] Cat: icon | Box: (310, 539, 363, 587)
#  → Caption: a black and white photo of a camera [BLIP]
# [18] Cat: icon | Box: (842, 527, 897, 588)
#  → Caption: a green arrow pointing up to the right [BLIP]
# [19] Cat: icon | Box: (355, 725, 374, 761)
#  → Caption: a black arrow on a white background [BLIP]
# [20] Cat: icon | Box: (306, 792, 343, 830)
#  → Caption: the green lantern logo, transparent png [BLIP]
# [21] Cat: icon | Box: (290, 863, 349, 930)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [22] Cat: icon | Box: (605, 937, 636, 963)
#  → Caption: a heart shaped object on a white background [BLIP]
# [23] Cat: icon | Box: (290, 996, 355, 1060)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [24] Cat: icon | Box: (5, 1070, 42, 1112)
#  → Caption: a black and white image of the letter e [BLIP]
# [25] Cat: icon | Box: (16, 1135, 77, 1187)
#  → Caption: a black background with the number 9 on it [BLIP]
# [26] Cat: icon | Box: (497, 1134, 559, 1197)
#  → Caption: the windows logo on a black background [BLIP]
# [27] Cat: icon | Box: (580, 1142, 620, 1183)
#  → Caption: a black and white photo of a person with a magni [BLIP]
# [28] Cat: icon | Box: (902, 1129, 969, 1188)
#  → Caption: a black and yellow square icon with the word talk [BLIP]
# [29] Cat: icon | Box: (978, 1139, 1033, 1190)
#  → Caption: a green spot on a black background [BLIP]
# [30] Cat: icon | Box: (1045, 1131, 1106, 1192)
#  → Caption: a black and white photo of a book on a black background [BLIP]
# [31] Cat: icon | Box: (1104, 1132, 1168, 1181)
#  → Caption: a black and white logo with the number 40 on it [BLIP]
# [32] Cat: icon | Box: (1178, 1140, 1222, 1189)
#  → Caption: an image of a yellow square on a black background [BLIP]
# [33] Cat: icon | Box: (1240, 1139, 1292, 1193)
#  → Caption: a folder icon on a black background [BLIP]
# [34] Cat: icon | Box: (1301, 1134, 1371, 1184)
#  → Caption: the google logo on a black background [BLIP]
# [35] Cat: icon | Box: (1525, 791, 1554, 836)
#  → Caption: a black and white photo of a man in a suit [BLIP]
# [36] Cat: icon | Box: (1558, 872, 1597, 908)
#  → Caption: a white background with black dots [BLIP]
# [37] Cat: icon | Box: (1566, 998, 1591, 1037)
#  → Caption: a black and white image of three circles on a white background [BLIP]
# [38] Cat: icon | Box: (1719, 1067, 1767, 1112)
#  → Caption: a pink heart on a white background [BLIP]
# [39] Cat: icon | Box: (1767, 1066, 1801, 1109)
#  → Caption: an image of a speech bubble [BLIP]
# [40] Cat: icon | Box: (1462, 1144, 1489, 1179)
#  → Caption: a black and white photo of a house [BLIP]
# [41] Cat: icon | Box: (1499, 1140, 1544, 1190)
#  → Caption: a black background with blue and green icons [BLIP]
# [42] Cat: icon | Box: (1554, 1139, 1589, 1193)
#  → Caption: a black and white logo with the letter a [BLIP]
# [43] Cat: icon | Box: (1604, 1141, 1649, 1186)
#  → Caption: a black and white logo with the letter p [BLIP]
# [44] Cat: icon | Box: (1665, 1136, 1702, 1185)
#  → Caption: a black background with a white wi logo [BLIP]
# [45] Cat: icon | Box: (1703, 1148, 1735, 1177)
#  → Caption: a black background with white text that says, ` ` ' [BLIP]
# [46] Cat: icon | Box: (1743, 1145, 1779, 1186)
#  → Caption: a black and white logo on a black background [BLIP]
# [47] Cat: icon | Box: (1570, 355, 1600, 387)
#  → Caption: a black and white image of a man ' s face [BLIP]
# [48] Cat: icon | Box: (1504, 300, 1540, 338)
#  → Caption: a cup of green tea on a white background [BLIP]
# [49] Cat: icon | Box: (1609, 72, 1649, 116)
#  → Caption: a black and white icon with a magnit [BLIP]
# [50] Cat: icon | Box: (1659, 72, 1695, 119)
#  → Caption: a white star on a black background [BLIP]
# [51] Cat: icon | Box: (1725, 11, 1768, 49)
#  → Caption: a black square with a white line in the middle [BLIP]
# [52] Cat: icon | Box: (1796, 12, 1834, 48)
#  → Caption: a black and white logo on a black background [BLIP]
# [53] Cat: icon | Box: (1867, 12, 1897, 49)
#  → Caption: a black background with a white x symbol [BLIP]
# [54] Cat: icon | Box: (1725, 68, 1772, 119)
#  → Caption: a black and white photo of a building with a clock on it [BLIP]
# [55] Cat: icon | Box: (1778, 67, 1807, 120)
#  → Caption: an image of a black and white background [BLIP]
# [56] Cat: icon | Box: (1810, 72, 1854, 123)
#  → Caption: a blue circle with the word cg on it [BLIP]
# [57] Cat: icon | Box: (1867, 71, 1900, 117)
#  → Caption: a black background with white dots [BLIP]
# [58] Cat: icon | Box: (1727, 129, 1749, 174)
#  → Caption: an image of a black and white background [BLIP]
# [59] Cat: icon | Box: (1756, 134, 1793, 169)
#  → Caption: a black and white image of a camera [BLIP]
# [60] Cat: icon | Box: (1772, 191, 1810, 242)
#  → Caption: a green background with a white outline of a speech bubble [BLIP]
# [61] Cat: icon | Box: (1830, 188, 1873, 245)
#  → Caption: a green square icon with white lines on it [BLIP]
# [62] Cat: icon | Box: (1895, 182, 1919, 202)
#  → Caption: a black and green icon with a white triangle [BLIP]
# [63] Cat: icon | Box: (1837, 1071, 1879, 1114)
#  → Caption: a black and white logo with the letter g on it [BLIP]
# [64] Cat: icon | Box: (1897, 1109, 1919, 1126)
#  → Caption: a black and white image of a triangle [BLIP]
# [65] 카테고리 '' → 캡션 생략
#
# ===== image11 (2).png =====
# [1] Cat: icon | Box: (2278, 639, 3142, 1376)
#  → Caption: a picture of a person with a cross on it [BLIP]
# [2] Cat: icon | Box: (440, 469, 1894, 1485)
#  → Caption: the logo of a mountain with a white background [BLIP]
#
# ===== image8 (2).png =====
# [1] Cat: icon | Box: (252, 715, 1224, 1625)
#  → Caption: a black and white photo in a circle [BLIP]
# [2] Cat: icon | Box: (1276, 721, 2214, 1638)
#  → Caption: a black and white image of an envelope [BLIP]
# [3] Cat: icon | Box: (2263, 715, 3237, 1664)
#  → Caption: a black circle with an image of a camera in it [BLIP]
#
# ===== image6 (1).png =====
# [1] Cat: icon | Box: (1677, 137, 1695, 167)
#  → Caption: a dark blue background with a white stripe [BLIP]
# [2] Cat: icon | Box: (1781, 138, 1798, 168)
#  → Caption: a dark blue background with a white stripe [BLIP]
# [3] Cat: icon | Box: (30, 133, 71, 172)
#  → Caption: a blue background with white text that says, ` ` ' [BLIP]
# [4] Cat: icon | Box: (206, 545, 272, 622)
#  → Caption: a white and blue icon of a church [BLIP]
# [5] Cat: icon | Box: (429, 545, 513, 619)
#  → Caption: a white circle with a blue icon of a video player on it [BLIP]
# [6] Cat: icon | Box: (670, 550, 731, 615)
#  → Caption: a computer screen with a bar chart on it [BLIP]
# [7] Cat: icon | Box: (891, 549, 966, 610)
#  → Caption: a blue and green icon of a megaphone [BLIP]
# [8] Cat: icon | Box: (1114, 542, 1200, 617)
#  → Caption: a white circle with a blue arrow in the center [BLIP]
# [9] Cat: icon | Box: (1340, 540, 1425, 623)
#  → Caption: a truck with a star on it ' s side [BLIP]
# [10] Cat: icon | Box: (1574, 542, 1656, 619)
#  → Caption: an icon of a credit card [BLIP]
# [11] Cat: icon | Box: (874, 727, 1036, 859)
#  → Caption: a blue and white logo with a smiley face in the middle [BLIP]
# [12] Cat: icon | Box: (326, 1004, 362, 1052)
#  → Caption: a blue background with a white envelope in the middle [BLIP]
# [13] Cat: icon | Box: (487, 1000, 519, 1058)
#  → Caption: a dark blue background with the letter i on it [BLIP]
# [14] Cat: icon | Box: (540, 1006, 570, 1046)
#  → Caption: a blue background with an arrow pointing up [BLIP]
# [15] Cat: icon | Box: (753, 1003, 775, 1052)
#  → Caption: a dark blue background with the letter i on it [BLIP]
# [16] Cat: icon | Box: (14, 1131, 74, 1190)
#  → Caption: a black background with the letter q and an orange circle [BLIP]
# [17] Cat: icon | Box: (439, 1130, 496, 1194)
#  → Caption: the windows 10 logo [BLIP]
# [18] Cat: icon | Box: (515, 1143, 553, 1186)
#  → Caption: a black and white photo of a person with a magni [BLIP]
# [19] Cat: icon | Box: (792, 1003, 845, 1055)
#  → Caption: an image of a computer screen with a blue background [BLIP]
# [20] Cat: icon | Box: (969, 1000, 1009, 1052)
#  → Caption: a dark blue background with the letter i on it [BLIP]
# [21] Cat: icon | Box: (1018, 1001, 1066, 1047)
#  → Caption: a blue background with an image of a wi logo [BLIP]
# [22] Cat: icon | Box: (1140, 1002, 1177, 1051)
#  → Caption: a dark blue background with a white stripe [BLIP]
# [23] Cat: icon | Box: (1190, 1005, 1234, 1054)
#  → Caption: an image of a printer on a blue background [BLIP]
# [24] Cat: icon | Box: (1370, 1003, 1402, 1053)
#  → Caption: a dark blue background with a white stripe [BLIP]
# [25] Cat: icon | Box: (1418, 1007, 1458, 1051)
#  → Caption: a blue background with an image of a computer screen [BLIP]
# [26] Cat: icon | Box: (1780, 963, 1856, 1038)
#  → Caption: a blue square icon with a magni on it [BLIP]
# [27] Cat: icon | Box: (848, 1133, 898, 1187)
#  → Caption: Chat application logo [CLIP (0.86)]
# [28] Cat: icon | Box: (914, 1143, 954, 1189)
#  → Caption: a green spot on a black background [BLIP]
# [29] Cat: icon | Box: (976, 1139, 1029, 1188)
#  → Caption: a black and white image of a book with the number 13 on it [BLIP]
# [30] Cat: icon | Box: (1049, 1132, 1099, 1187)
#  → Caption: a black and white logo with the number 40 on it [BLIP]
# [31] Cat: icon | Box: (1109, 1134, 1160, 1188)
#  → Caption: an image of a square in yellow and red [BLIP]
# [32] Cat: icon | Box: (1172, 1135, 1228, 1188)
#  → Caption: a folder icon on a black background [BLIP]
# [33] Cat: icon | Box: (1239, 1141, 1294, 1192)
#  → Caption: the google chrome logo [BLIP]
# [34] Cat: icon | Box: (1304, 1132, 1363, 1186)
#  → Caption: the google logo on an iphone [BLIP]
# [35] Cat: icon | Box: (1458, 1146, 1497, 1181)
#  → Caption: a black and white photo of a house [BLIP]
# [36] Cat: icon | Box: (1498, 1139, 1550, 1191)
#  → Caption: a black background with blue and green logos [BLIP]
# [37] Cat: icon | Box: (1551, 1145, 1595, 1185)
#  → Caption: the letter a on a black background [BLIP]
# [38] Cat: icon | Box: (1609, 1138, 1660, 1185)
#  → Caption: a black and white logo with the letter p [BLIP]
# [39] Cat: icon | Box: (1660, 1138, 1707, 1189)
#  → Caption: a black background with a wi logo on it [BLIP]
# [40] Cat: icon | Box: (1701, 1146, 1740, 1180)
#  → Caption: a black and white logo with the letter cx [BLIP]
# [41] Cat: icon | Box: (1740, 1144, 1778, 1186)
#  → Caption: a black and white logo on a black background [BLIP]
# [42] Cat: icon | Box: (1568, 140, 1587, 168)
#  → Caption: a dark blue background with a white stripe [BLIP]
# [43] Cat: icon | Box: (1875, 76, 1894, 118)
#  → Caption: a black and white image of three circles on a dark background [BLIP]
# [44] Cat: icon | Box: (1737, 74, 1777, 113)
#  → Caption: a white star on a black background [BLIP]
# [45] Cat: icon | Box: (1687, 71, 1730, 110)
#  → Caption: a black and white image of a mag glass [BLIP]
# [46] Cat: icon | Box: (1866, 7, 1905, 50)
#  → Caption: the x logo on a black background [BLIP]
# [47] Cat: icon | Box: (1796, 9, 1835, 51)
#  → Caption: a black and white logo on a black background [BLIP]
# [48] Cat: icon | Box: (184, 76, 222, 111)
#  → Caption: a black and white circle with two circles in the center [BLIP]
# [49] Cat: icon | Box: (424, 9, 462, 47)
#  → Caption: a white cross on a black background [BLIP]
# [50] Cat: icon | Box: (369, 15, 398, 47)
#  → Caption: a black and white logo with the letter x on it [BLIP]
# [51] Cat: icon | Box: (67, 12, 98, 52)
#  → Caption: a blue star on a black background [BLIP]
# [52] Cat: icon | Box: (118, 77, 155, 119)
#  → Caption: a black and white logo with the letter g [BLIP]
# [53] Cat: icon | Box: (72, 78, 107, 116)
#  → Caption: a black and white image of an arrow [BLIP]
# [54] Cat: icon | Box: (18, 80, 54, 111)
#  → Caption: a black background with a white arrow on it [BLIP]
# [55] Cat: icon | Box: (7, 12, 48, 52)
#  → Caption: a black and white icon with a check mark on it [BLIP]
#
# ===== image2.png =====
# [1] 카테고리 '' → 캡션 생략
# [2] 카테고리 '' → 캡션 생략
# [3] 카테고리 '' → 캡션 생략
# [4] 카테고리 '' → 캡션 생략
# [5] Cat: icon | Box: (228, 13, 345, 73)
#  → Caption: a black and white image of a cloud [BLIP]
# [6] Cat: icon | Box: (695, 120, 756, 183)
#  → Caption: a purple lightning bolt on a black background [BLIP]
# [7] Cat: icon | Box: (1836, 16, 1892, 72)
#  → Caption: a black and white photo of a person with a magni [BLIP]
# [8] Cat: icon | Box: (2577, 119, 2643, 182)
#  → Caption: an image of a black square with two crosses on it [BLIP]
# [9] Cat: icon | Box: (2589, 24, 2652, 63)
#  → Caption: a black background with white circles on it [BLIP]
# [10] Cat: icon | Box: (2018, 359, 2066, 411)
#  → Caption: an apple logo on a black background [BLIP]
# [11] Cat: icon | Box: (2269, 356, 2334, 417)
#  → Caption: the google play logo [BLIP]
#
# ===== image3 (2).png =====
# [1] Cat: icon | Box: (1239, 495, 1551, 836)
#  → Caption: a black and white image of a square [BLIP]
# [2] Cat: icon | Box: (801, 508, 1131, 833)
#  → Caption: a black and white logo with the letter g [BLIP]
# [3] Cat: icon | Box: (347, 498, 685, 838)
#  → Caption: a clock icon on a white background [BLIP]
# [4] Cat: icon | Box: (348, 934, 696, 1274)
#  → Caption: a black and white image of a pencil [BLIP]
# [5] Cat: icon | Box: (783, 931, 1131, 1266)
#  → Caption: a black and white image of a play button [BLIP]
# [6] Cat: icon | Box: (1257, 939, 1533, 1292)
#  → Caption: a black and white logo with the letter z on it [BLIP]
# [7] Cat: icon | Box: (1229, 1403, 1580, 1707)
#  → Caption: a black and white image of a car [BLIP]
# [8] Cat: icon | Box: (788, 1377, 1118, 1725)
#  → Caption: a black and white image of a smiling face [BLIP]
# [9] Cat: icon | Box: (340, 1367, 696, 1730)
#  → Caption: Phone symbol [CLIP (0.90)]
# [10] Cat: icon | Box: (2907, 1390, 3194, 1697)
#  → Caption: a blue and white logo with the letter t on it [BLIP]
# [11] Cat: icon | Box: (2026, 516, 2299, 823)
#  → Caption: a person in a blue suit and tie [BLIP]
# [12] Cat: icon | Box: (2454, 508, 2760, 800)
#  → Caption: a white background with blue circles on it [BLIP]
# [13] Cat: icon | Box: (2900, 508, 3201, 818)
#  → Caption: a circle with four circles in the middle [BLIP]
# [14] Cat: icon | Box: (2882, 975, 3193, 1256)
#  → Caption: a blue truck with an arrow on the side [BLIP]
# [15] Cat: icon | Box: (2448, 957, 2776, 1266)
#  → Caption: a white background with a blue triangle in the middle [BLIP]
# [16] Cat: icon | Box: (2023, 962, 2307, 1253)
#  → Caption: a blue beakle with two gears on it [BLIP]
# [17] Cat: icon | Box: (2005, 1403, 2340, 1681)
#  → Caption: a group of people holding puzzle pieces [BLIP]
# [18] Cat: icon | Box: (2443, 1395, 2768, 1704)
#  → Caption: a blue sheep standing in front of a white background [BLIP]
# [19] 카테고리 '' → 캡션 생략
# [20] 카테고리 '' → 캡션 생략
# [21] 카테고리 '' → 캡션 생략
# [22] 카테고리 '' → 캡션 생략
#
# ===== image12 (1).png =====
# [1] Cat: icon | Box: (1793, 20, 1831, 54)
#  → Caption: a black and white logo on a black background [BLIP]
# [2] Cat: icon | Box: (1867, 20, 1900, 51)
#  → Caption: a black and white logo with the letter x [BLIP]
# [3] 카테고리 '' → 캡션 생략
# [4] 카테고리 '' → 캡션 생략
# [5] 카테고리 '' → 캡션 생략
# [6] Cat: icon | Box: (1719, 19, 1758, 53)
#  → Caption: an image of a black square with white lines [BLIP]
# [7] 카테고리 '' → 캡션 생략
# [8] 카테고리 '' → 캡션 생략
# [9] 카테고리 '' → 캡션 생략
# [10] Cat: icon | Box: (41, 1022, 84, 1068)
#  → Caption: a black and white logo with the words [BLIP]
# [11] Cat: icon | Box: (20, 1133, 73, 1182)
#  → Caption: a black background with the number 9 on it [BLIP]
# [12] Cat: icon | Box: (444, 1139, 495, 1190)
#  → Caption: the windows 10 logo [BLIP]
# [13] Cat: icon | Box: (516, 1149, 552, 1180)
#  → Caption: a black and white image of a mag glass [BLIP]
# [14] Cat: icon | Box: (846, 1140, 897, 1187)
#  → Caption: a yellow square with the word talk on it [BLIP]
# [15] Cat: icon | Box: (914, 1138, 962, 1186)
#  → Caption: a green spot logo on a black background [BLIP]
# [16] Cat: icon | Box: (978, 1139, 1029, 1189)
#  → Caption: a black and white image of a book on a black background [BLIP]
# [17] Cat: icon | Box: (1048, 1140, 1098, 1183)
#  → Caption: a black and white logo with the number 40 on it [BLIP]
# [18] Cat: icon | Box: (16, 15, 56, 54)
#  → Caption: a black background with a green folder icon [BLIP]
# [19] Cat: icon | Box: (38, 81, 85, 125)
#  → Caption: a black background with a green house icon [BLIP]
# [20] Cat: icon | Box: (41, 176, 85, 222)
#  → Caption: a black and white logo on a black background [BLIP]
# [21] Cat: icon | Box: (148, 166, 176, 188)
#  → Caption: a white check mark on a black background [BLIP]
# [22] Cat: icon | Box: (36, 274, 86, 313)
#  → Caption: a black and white logo with the words [BLIP]
# [23] Cat: icon | Box: (220, 488, 255, 523)
#  → Caption: a black and white image of a mag glass [BLIP]
# [24] Cat: icon | Box: (195, 693, 252, 750)
#  → Caption: a black background with an image of the microsoft logo [BLIP]
# [25] Cat: icon | Box: (195, 779, 249, 835)
#  → Caption: a black background with an image of the microsoft logo [BLIP]
# [26] Cat: icon | Box: (197, 858, 246, 921)
#  → Caption: a black background with a green and white logo [BLIP]
# [27] Cat: icon | Box: (195, 942, 248, 1004)
#  → Caption: a black background with a green and white logo [BLIP]
# [28] Cat: icon | Box: (195, 1030, 248, 1088)
#  → Caption: a black background with a green and white logo [BLIP]
# [29] Cat: icon | Box: (41, 924, 83, 970)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [30] Cat: icon | Box: (1114, 1143, 1159, 1185)
#  → Caption: an image of a square in yellow and red [BLIP]
# [31] Cat: icon | Box: (1177, 1142, 1226, 1186)
#  → Caption: a folder icon on a black background [BLIP]
# [32] Cat: icon | Box: (1244, 1140, 1292, 1187)
#  → Caption: the google chrome logo [BLIP]
# [33] Cat: icon | Box: (1311, 1141, 1358, 1185)
#  → Caption: a green folder icon on a black background [BLIP]
# [34] Cat: icon | Box: (1459, 1143, 1493, 1180)
#  → Caption: a black and white photo of a house [BLIP]
# [35] Cat: icon | Box: (1505, 1144, 1545, 1181)
#  → Caption: a black background with a blue and green shield icon [BLIP]
# [36] Cat: icon | Box: (1557, 1140, 1588, 1189)
#  → Caption: a black and white logo [BLIP]
# [37] Cat: icon | Box: (1609, 1142, 1649, 1183)
#  → Caption: a black and white logo with the letter p [BLIP]
# [38] Cat: icon | Box: (1669, 1145, 1701, 1181)
#  → Caption: a black background with a white wi logo [BLIP]
# [39] Cat: icon | Box: (1705, 1148, 1739, 1182)
#  → Caption: a black background with white text that says, ` ` ' [BLIP]
# [40] Cat: icon | Box: (1740, 1143, 1779, 1182)
#  → Caption: a black and white logo on a black background [BLIP]
# [41] Cat: icon | Box: (1895, 1104, 1917, 1126)
#  → Caption: a white triangle on a black background [BLIP]
# [42] Cat: icon | Box: (1895, 142, 1916, 164)
#  → Caption: a white triangle on a black background [BLIP]
# [43] Cat: icon | Box: (1800, 162, 1834, 190)
#  → Caption: a green arrow on a black background [BLIP]
# [44] Cat: icon | Box: (1494, 3, 1551, 67)
#  → Caption: a white circle on a black background [BLIP]
# [45] Cat: icon | Box: (1568, 13, 1619, 56)
#  → Caption: a black and white logo with the words [BLIP]
# [46] Cat: icon | Box: (1650, 18, 1679, 52)
#  → Caption: a black background with a white question mark [BLIP]
#
# ===== image4.png =====
# [1] Cat: icon | Box: (1714, 400, 1767, 457)
#  → Caption: a blue circle on a white background [BLIP]
# [2] Cat: icon | Box: (1720, 499, 1763, 556)
#  → Caption: a black and yellow logo on a white background [BLIP]
# [3] Cat: icon | Box: (1584, 1299, 1748, 1446)
#  → Caption: a green square icon on a white background [BLIP]
# [4] Cat: icon | Box: (1877, 1284, 1993, 1454)
#  → Caption: the google logo with a carrot on it [BLIP]
# [5] 카테고리 '' → 캡션 생략
# [6] 카테고리 '' → 캡션 생략
# [7] 카테고리 '' → 캡션 생략
# [8] 카테고리 '' → 캡션 생략
# [9] Cat: icon | Box: (263, 157, 319, 215)
#  → Caption: a clock icon on a white background [BLIP]
# [10] Cat: icon | Box: (432, 163, 480, 218)
#  → Caption: a black and white image of a wi logo [BLIP]
# [11] Cat: icon | Box: (2506, 21, 2560, 85)
#  → Caption: a black and white icon of a bell [BLIP]
# [12] Cat: icon | Box: (2592, 21, 2648, 87)
#  → Caption: a black and white image of a mag glass [BLIP]
# [13] Cat: icon | Box: (66, 156, 122, 219)
#  → Caption: a black and white image of an arrow [BLIP]
# [14] Cat: icon | Box: (2694, 170, 2735, 210)
#  → Caption: a black triangle on a white background [BLIP]
# [15] Cat: icon | Box: (2785, 156, 2821, 218)
#  → Caption: a black and white photo of a man in a suit [BLIP]
# [16] Cat: icon | Box: (2712, 1012, 2749, 1052)
#  → Caption: a black heart on a white background [BLIP]
# [17] Cat: icon | Box: (2017, 997, 2050, 1035)
#  → Caption: a black heart on a white background [BLIP]
# [18] Cat: icon | Box: (1516, 999, 1553, 1039)
#  → Caption: a blue square icon with a question mark [BLIP]
# [19] Cat: icon | Box: (1308, 1015, 1344, 1053)
#  → Caption: a black heart on a white background [BLIP]
# [20] Cat: icon | Box: (812, 1018, 849, 1054)
#  → Caption: a blue square icon with a question mark [BLIP]
# [21] Cat: icon | Box: (604, 1020, 640, 1053)
#  → Caption: a black heart on a white background [BLIP]
# [22] Cat: icon | Box: (311, 1193, 461, 1326)
#  → Caption: a white icon with two stacks of coins [BLIP]
#
# ===== image7.png =====
# [1] 카테고리 '' → 캡션 생략
# [2] 카테고리 '' → 캡션 생략
# [3] 카테고리 '' → 캡션 생략
# [4] 카테고리 '' → 캡션 생략
# [5] Cat: icon | Box: (29, 182, 117, 270)
#  → Caption: the logo of a person in a circle [BLIP]
# [6] Cat: icon | Box: (38, 327, 104, 387)
#  → Caption: a red background with a white logo [BLIP]
# [7] Cat: icon | Box: (46, 457, 103, 520)
#  → Caption: the logo for a company that sells products [BLIP]
# [8] Cat: icon | Box: (44, 585, 106, 651)
#  → Caption: a red background with a white square icon of a calendar [BLIP]
# [9] Cat: icon | Box: (37, 709, 109, 778)
#  → Caption: a red and white icon with the letter e on it [BLIP]
# [10] Cat: icon | Box: (39, 837, 111, 906)
#  → Caption: a clock on a red background [BLIP]
# [11] Cat: icon | Box: (43, 965, 104, 1029)
#  → Caption: a red background with an image of a document [BLIP]
# [12] Cat: icon | Box: (36, 1090, 108, 1158)
#  → Caption: the body shop organic face cream [BLIP]
# [13] Cat: icon | Box: (44, 1218, 104, 1280)
#  → Caption: a red square with a question mark on it [BLIP]
# [14] Cat: icon | Box: (36, 1396, 112, 1450)
#  → Caption: a red square with the letter k on it [BLIP]
# [15] Cat: icon | Box: (621, 1390, 649, 1421)
#  → Caption: a black and white image of a triangle [BLIP]
# [16] Cat: icon | Box: (211, 251, 251, 299)
#  → Caption: a house in the middle of nowhere [BLIP]
# [17] Cat: icon | Box: (214, 310, 255, 361)
#  → Caption: a black and white icon of a megaphone [BLIP]
# [18] Cat: icon | Box: (211, 368, 255, 421)
#  → Caption: a black and white image of a document [BLIP]
# [19] Cat: icon | Box: (209, 430, 250, 477)
#  → Caption: a black and white image of a clipboard on a white background [BLIP]
# [20] Cat: icon | Box: (213, 486, 252, 536)
#  → Caption: a black and white image of a calendar [BLIP]
# [21] Cat: icon | Box: (216, 556, 249, 593)
#  → Caption: a black square on a white background [BLIP]
# [22] Cat: icon | Box: (209, 614, 257, 651)
#  → Caption: a black and white logo on a white background [BLIP]
# [23] Cat: icon | Box: (210, 672, 255, 715)
#  → Caption: a black and white photo of a computer screen [BLIP]
# [24] Cat: icon | Box: (211, 729, 254, 773)
#  → Caption: a black and white image of a document [BLIP]
# [25] Cat: icon | Box: (212, 789, 254, 837)
#  → Caption: a black and white image of a square frame [BLIP]
# [26] Cat: icon | Box: (211, 851, 252, 896)
#  → Caption: a black and white image of a document [BLIP]
# [27] Cat: icon | Box: (211, 912, 257, 962)
#  → Caption: a black and white image of a man ' s face [BLIP]
# [28] Cat: icon | Box: (628, 264, 684, 312)
#  → Caption: a blue paper airplane icon on a white background [BLIP]
# [29] Cat: icon | Box: (1644, 750, 1834, 940)
#  → Caption: a black and white logo with the word ssg [BLIP]
# [30] Cat: icon | Box: (208, 44, 276, 110)
#  → Caption: a white background with a red stripe [BLIP]
#
# ===== image13 (2).png =====
# [1] Cat: icon | Box: (646, 620, 1261, 1237)
#  → Caption: a black and white icon of an envelope with stars [BLIP]
# [2] Cat: icon | Box: (1273, 625, 1915, 1213)
#  → Caption: a black and white icon of a video player [BLIP]
# [3] Cat: icon | Box: (1945, 632, 2281, 1227)
#  → Caption: a microphone with a star on top of it [BLIP]
# [4] Cat: icon | Box: (2333, 672, 2836, 1225)
#  → Caption: a mag glass with a star on top of it [BLIP]
# [5] Cat: icon | Box: (108, 655, 594, 1257)
#  → Caption: a black and white icon of a document with a star [BLIP]
# [6] 카테고리 '' → 캡션 생략
#
# ===== image5.png =====
# [1] Cat: icon | Box: (96, 1505, 135, 1539)
#  → Caption: a black background with a white x symbol in the middle [BLIP]
# [2] Cat: icon | Box: (13, 369, 96, 451)
#  → Caption: Phone symbol [CLIP (0.93)]
# [3] Cat: icon | Box: (15, 484, 102, 571)
#  → Caption: the number 1 on a black background [BLIP]
# [4] Cat: icon | Box: (19, 602, 88, 678)
#  → Caption: a black and white image of a beakle [BLIP]
# [5] Cat: icon | Box: (18, 1285, 92, 1360)
#  → Caption: a black and white photo of a man ' s face [BLIP]
# [6] 카테고리 '' → 캡션 생략
# [7] 카테고리 '' → 캡션 생략
# [8] 카테고리 '' → 캡션 생략
# [9] Cat: icon | Box: (17, 27, 89, 111)
#  → Caption: a black and white photo of a man in a suit [BLIP]
# [10] Cat: icon | Box: (17, 136, 90, 225)
#  → Caption: a black square with a magni on it [BLIP]
# [11] Cat: icon | Box: (18, 252, 96, 347)
#  → Caption: a black and white logo with the letter g on it [BLIP]
# [12] Cat: icon | Box: (18, 1403, 92, 1470)
#  → Caption: a black and white image of a flower [BLIP]
# [13] Cat: icon | Box: (17, 1502, 64, 1544)
#  → Caption: a blue background with a white cross on it [BLIP]
# [14] Cat: icon | Box: (120, 1455, 155, 1488)
#  → Caption: a black background with a white check mark on it [BLIP]
# [15] Cat: icon | Box: (164, 1505, 202, 1541)
#  → Caption: a white triangle on a black background [BLIP]
# [16] Cat: icon | Box: (284, 1504, 320, 1542)
#  → Caption: a black and white image of a radio tower [BLIP]
# [17] Cat: icon | Box: (376, 1506, 416, 1546)
#  → Caption: a black and white logo with the letter c [BLIP]
# [18] Cat: icon | Box: (549, 24, 590, 74)
#  → Caption: a digital clock with yellow numbers on it [BLIP]
# [19] Cat: icon | Box: (1021, 29, 1059, 73)
#  → Caption: a black and white photo of a gas station [BLIP]
# [20] Cat: icon | Box: (1455, 29, 1491, 71)
#  → Caption: a black background with the letter c on it [BLIP]
# [21] Cat: icon | Box: (1746, 32, 1777, 69)
#  → Caption: the letter c on a black background [BLIP]
# [22] Cat: icon | Box: (2034, 32, 2066, 67)
#  → Caption: a black background with the letter c on it [BLIP]
# [23] Cat: icon | Box: (2322, 31, 2354, 69)
#  → Caption: a black background with the letter c on it [BLIP]
# [24] Cat: icon | Box: (2609, 33, 2640, 69)
#  → Caption: a black background with the letter c on it [BLIP]
# [25] Cat: icon | Box: (2798, 28, 2846, 72)
#  → Caption: a black and white photo of a man in a suit [BLIP]
# [26] Cat: icon | Box: (2864, 34, 2901, 68)
#  → Caption: a black background with white circles on it [BLIP]
# [27] Cat: icon | Box: (1781, 1504, 1829, 1544)
#  → Caption: a black and white icon with a magnit [BLIP]
# [28] Cat: icon | Box: (2340, 1504, 2384, 1543)
#  → Caption: a black and white image of the letter o [BLIP]
# [29] Cat: icon | Box: (2503, 1503, 2537, 1540)
#  → Caption: a black and white logo with the letter p [BLIP]
# [30] Cat: icon | Box: (2682, 1504, 2721, 1540)
#  → Caption: a white circle on a black background [BLIP]
# [31] Cat: icon | Box: (2865, 1503, 2900, 1544)
#  → Caption: a bell icon on a black background [BLIP]
# [32] Cat: icon | Box: (933, 29, 976, 69)
#  → Caption: a black background with a white x symbol on it [BLIP]
#
# ===== image4 (2).png =====
# [1] Cat: icon | Box: (897, 337, 1311, 737)
#  → Caption: WhatsApp logo [CLIP (0.99)]
# [2] Cat: icon | Box: (1472, 344, 1892, 739)
#  → Caption: a blue circle with a check mark on it [BLIP]
# [3] 카테고리 '' → 캡션 생략
# [4] 카테고리 '' → 캡션 생략
# [5] 카테고리 '' → 캡션 생략
# [6] Cat: icon | Box: (323, 314, 722, 747)
#  → Caption: a blue and yellow icon with an arrow in the middle of it [BLIP]
#
# ===== image1.png =====
# [1] Cat: icon | Box: (37, 35, 98, 87)
#  → Caption: a black and white logo with the letter e on it [BLIP]
# [2] Cat: icon | Box: (1388, 267, 1514, 411)
#  → Caption: the google chrome logo [BLIP]
# [3] Cat: icon | Box: (1000, 580, 1049, 646)
#  → Caption: a black and white image of a mag glass [BLIP]
# [4] Cat: icon | Box: (2714, 29, 2772, 102)
#  → Caption: a black and white image of several squares [BLIP]
# [5] 카테고리 '' → 캡션 생략
# [6] 카테고리 '' → 캡션 생략
# [7] 카테고리 '' → 캡션 생략
# [8] 카테고리 '' → 캡션 생략
# [9] 카테고리 '' → 캡션 생략
# [10] 카테고리 '' → 캡션 생략
# [11] Cat: icon | Box: (2802, 17, 2882, 99)
#  → Caption: a brown circle with the letters f and f [BLIP]
# [12] Cat: icon | Box: (651, 1003, 692, 1046)
#  → Caption: a blue circle with the letter i in it [BLIP]
# [13] Cat: icon | Box: (2200, 1021, 2249, 1072)
# ...
#  → Caption: an image of a computer screen with a check mark on it [BLIP]
# [5] Cat: icon | Box: (842, 891, 907, 954)
#  → Caption: a blue envelope with an orange cross on it [BLIP]
# [6] Cat: icon | Box: (1005, 876, 1052, 921)
#  → Caption: an image of a laptop with a white background [BLIP]
# [7] Cat: icon | Box: (1197, 877, 1244, 922)
#  → Caption: a black and white photo of a building [BLIP]
# [8] Cat: icon | Box: (1006, 947, 1053, 992)
#  → Caption: a black and white image of a stack of coins [BLIP]
# [9] Cat: icon | Box: (1201, 946, 1249, 991)
#  → Caption: a black and white logo with the letter g on it [BLIP]
# [10] Cat: icon | Box: (1388, 945, 1435, 990)
#  → Caption: a man with a mustache and a hat [BLIP]
# [11] Cat: icon | Box: (1390, 877, 1438, 922)
#  → Caption: a black and white photo of a speech bubble [BLIP]
# [12] Cat: icon | Box: (1412, 746, 1447, 777)
#  → Caption: a black and white logo on a white background [BLIP]
# [13] Cat: icon | Box: (902, 820, 921, 841)
#  → Caption: a black and white photo of the letter k [BLIP]
# [14] Cat: icon | Box: (699, 663, 747, 708)
#  → Caption: the logo for the company [BLIP]
# [15] Cat: icon | Box: (1506, 246, 1554, 291)
#  → Caption: a brown square with the letter e on it [BLIP]
# [16] Cat: icon | Box: (1540, 175, 1566, 205)
#  → Caption: a blue background with a white speech bubble [BLIP]
# [17] Cat: icon | Box: (1417, 181, 1435, 200)
#  → Caption: a white triangle on a blue background [BLIP]
# [18] Cat: icon | Box: (1520, 180, 1537, 199)
#  → Caption: a white triangle on a blue background [BLIP]
# [19] Cat: icon | Box: (335, 171, 369, 207)
#  → Caption: the s logo on a blue background [BLIP]
# [20] Cat: icon | Box: (369, 668, 416, 713)
#  → Caption: an orange square icon with a white arrow pointing to the right [BLIP]
#
# ===== 스크린샷 2025-06-08 201434.png =====
# [1] Cat: icon | Box: (1103, 868, 1171, 931)
#  → Caption: a whiteboard with a blue arrow on it [BLIP]
# [2] Cat: icon | Box: (995, 869, 1063, 932)
#  → Caption: a blue and white umbrella [BLIP]
# [3] Cat: icon | Box: (1065, 519, 1086, 555)
#  → Caption: a blue background with a white arrow on it [BLIP]
# [4] Cat: icon | Box: (1034, 519, 1053, 555)
#  → Caption: a blue background with the letter k on it [BLIP]
# [5] Cat: icon | Box: (1388, 605, 1420, 641)
#  → Caption: a black and white image of the letter k [BLIP]
# [6] Cat: icon | Box: (465, 868, 533, 930)
#  → Caption: a bag of money icon [BLIP]
# [7] Cat: icon | Box: (354, 867, 422, 930)
#  → Caption: a pig with a blue button on it ' s back [BLIP]
# [8] Cat: icon | Box: (891, 866, 959, 928)
#  → Caption: a man with a hat on his head [BLIP]
# [9] Cat: icon | Box: (783, 863, 851, 926)
#  → Caption: an image of a washing machine [BLIP]
# [10] Cat: icon | Box: (674, 865, 747, 929)
#  → Caption: a white and blue logo with the words [BLIP]
# [11] 카테고리 '' → 캡션 생략
# [12] Cat: icon | Box: (570, 867, 637, 929)
#  → Caption: a computer with a bar chart on the screen [BLIP]
# [13] Cat: icon | Box: (986, 519, 1018, 556)
#  → Caption: an image of a light blue background [BLIP]
# [14] Cat: icon | Box: (1465, 863, 1540, 925)
#  → Caption: a blue gift box with a white bow [BLIP]
# [15] Cat: icon | Box: (1359, 866, 1434, 928)
#  → Caption: a person with a credit card in their hand [BLIP]
# [16] Cat: icon | Box: (1254, 864, 1322, 926)
#  → Caption: a computer with a check mark on it [BLIP]
#
# ===== 스크린샷 2025-06-08 203539.png =====
# [1] Cat: icon | Box: (1606, 681, 1653, 725)
#  → Caption: a black and white photo of a man in a suit [BLIP]
# [2] Cat: icon | Box: (1608, 876, 1656, 920)
#  → Caption: a black and white photo of a computer screen [BLIP]
# [3] 카테고리 '' → 캡션 생략
# [4] 카테고리 '' → 캡션 생략
# [5] Cat: icon | Box: (1608, 493, 1656, 536)
#  → Caption: an image of a calculaing machine [BLIP]
# [6] Cat: icon | Box: (1471, 652, 1535, 701)
#  → Caption: a white triangle on a blue background [BLIP]
# [7] Cat: icon | Box: (1337, 647, 1401, 697)
#  → Caption: a blue background with an image of a document [BLIP]
# [8] Cat: icon | Box: (1206, 650, 1282, 699)
#  → Caption: a blue background with an image of the word op on it [BLIP]
# [9] Cat: icon | Box: (1090, 648, 1154, 698)
#  → Caption: the facebook logo [BLIP]
# [10] Cat: icon | Box: (956, 650, 1020, 699)
#  → Caption: a blue square icon with an arrow pointing to the right [BLIP]
# [11] Cat: icon | Box: (828, 649, 892, 699)
#  → Caption: a white icon with the word i on it [BLIP]
# [12] Cat: icon | Box: (374, 193, 423, 243)
#  → Caption: a blue and white logo [BLIP]
# [13] Cat: icon | Box: (1611, 586, 1659, 630)
#  → Caption: a black and white photo of a computer screen [BLIP]
# [14] Cat: icon | Box: (1609, 776, 1656, 820)
#  → Caption: an image of a lock on a white background [BLIP]
#
# ===== Screenshot 2025-06-09 at 4.45.19 PM.png =====
# [1] Cat: icon | Box: (2073, 976, 2170, 1073)
#  → Caption: Phone symbol [CLIP (0.89)]
# [2] Cat: icon | Box: (2509, 27, 2573, 91)
#  → Caption: a black and white logo on a black background [BLIP]
# [3] Cat: icon | Box: (2213, 27, 2280, 91)
#  → Caption: a black and white logo with the letter e [BLIP]
# [4] Cat: icon | Box: (2100, 24, 2183, 99)
#  → Caption: an american flag on a black background [BLIP]
# [5] Cat: icon | Box: (1989, 19, 2069, 99)
#  → Caption: a black square icon with a magni on it [BLIP]
# [6] Cat: icon | Box: (112, 527, 209, 620)
#  → Caption: a black and white logo on a gray background [BLIP]
# [7] Cat: icon | Box: (2731, 517, 2841, 627)
#  → Caption: a black and white image of an arrow [BLIP]
# [8] Cat: icon | Box: (2545, 1301, 2625, 1374)
#  → Caption: a white background with a red speech bubble [BLIP]
# [9] Cat: icon | Box: (2525, 1415, 2615, 1495)
#  → Caption: an image of the phone icon [BLIP]
#
# ===== Screenshot 2025-06-09 at 4.53.33 PM.png =====
# [1] Cat: icon | Box: (310, 192, 350, 236)
#  → Caption: a white background with a blue check mark on it [BLIP]
# [2] Cat: icon | Box: (55, 35, 146, 129)
#  → Caption: the walco logo on a blue background [BLIP]
# [3] Cat: icon | Box: (189, 45, 270, 125)
#  → Caption: a hand holding a passport in front of a blue background [BLIP]
# [4] Cat: icon | Box: (746, 61, 783, 98)
#  → Caption: a blue background with a white check mark [BLIP]
# [5] Cat: icon | Box: (2174, 41, 2255, 129)
#  → Caption: a blue circle with the letter q on it [BLIP]
# [6] Cat: icon | Box: (2315, 61, 2355, 102)
#  → Caption: a white heart on a blue background [BLIP]
# [7] Cat: icon | Box: (2553, 58, 2603, 108)
#  → Caption: a white icon on a blue background [BLIP]
# [8] Cat: icon | Box: (2794, 18, 2882, 92)
#  → Caption: a shopping cart with a coin in it [BLIP]
# [9] Cat: icon | Box: (62, 182, 115, 246)
#  → Caption: a white background with blue squares on it [BLIP]
# [10] Cat: icon | Box: (384, 189, 437, 239)
#  → Caption: a white background with blue circles on it [BLIP]
# [11] Cat: icon | Box: (2835, 199, 2885, 243)
#  → Caption: a white background with a blue check mark on it [BLIP]
#
# ===== Screenshot 2025-06-09 at 4.55.53 PM.png =====
# [1] Cat: icon | Box: (2044, 18, 2088, 65)
#  → Caption: a black and white photo of a video player [BLIP]
# [2] Cat: icon | Box: (2232, 15, 2279, 65)
#  → Caption: a black and white image of headphones [BLIP]
# [3] Cat: icon | Box: (2598, 11, 2655, 65)
#  → Caption: a black and white image of a mag glass [BLIP]
# [4] Cat: icon | Box: (177, 5, 302, 75)
#  → Caption: the cnn logo [BLIP]
# [5] Cat: icon | Box: (2218, 457, 2269, 508)
#  → Caption: a black and white image of an audio player [BLIP]
# [6] Cat: icon | Box: (2592, 459, 2638, 505)
#  → Caption: a black and white logo with the words ccc [BLIP]
# [7] Cat: icon | Box: (2679, 460, 2726, 507)
#  → Caption: a black background with a white logo on it [BLIP]
# [8] Cat: icon | Box: (2769, 459, 2815, 505)
#  → Caption: a black and white logo with the letter c on it [BLIP]
# [9] Cat: icon | Box: (2723, 390, 2780, 447)
#  → Caption: a black and white icon with an arrow in the middle [BLIP]
# [10] 카테고리 '' → 캡션 생략
# [11] Cat: icon | Box: (1742, 18, 1782, 65)
#  → Caption: a black and white logo with the letter v on it [BLIP]
# [12] Cat: icon | Box: (94, 15, 144, 65)
#  → Caption: a black and white image of the letter e [BLIP]
#
# ===== Screenshot 2025-06-09 at 5.13.55 PM.png =====
# [1] Cat: icon | Box: (2119, 1323, 2169, 1370)
#  → Caption: a black and white photo of a man in the dark [BLIP]
# [2] Cat: icon | Box: (40, 26, 107, 97)
#  → Caption: the microsoft logo [BLIP]
# [3] Cat: icon | Box: (492, 41, 540, 87)
#  → Caption: an image of a rainbow colored cube on a brown background [BLIP]
# [4] Cat: icon | Box: (1256, 34, 1317, 98)
#  → Caption: the sky is blue [BLIP]
# [5] Cat: icon | Box: (2285, 20, 2363, 104)
#  → Caption: a white circle with an image of a building in the background [BLIP]
# [6] Cat: icon | Box: (2528, 31, 2601, 104)
#  → Caption: an image of a white circle with a black and white logo on it [BLIP]
# [7] Cat: icon | Box: (2729, 19, 2794, 102)
#  → Caption: Phone symbol [CLIP (0.94)]
# [8] Cat: icon | Box: (2813, 34, 2870, 90)
#  → Caption: an image of a white line on a brown background [BLIP]
# [9] Cat: icon | Box: (2291, 353, 2344, 412)
#  → Caption: a blue and white microphone icon [BLIP]
# [10] Cat: icon | Box: (2356, 353, 2423, 413)
#  → Caption: a blue and white logo with the letter g on it [BLIP]
# [11] Cat: icon | Box: (2460, 332, 2562, 433)
#  → Caption: a white circle with the letter q on it [BLIP]
# [12] Cat: icon | Box: (248, 1004, 341, 1098)
#  → Caption: a clock sitting on top of a wooden table [BLIP]
# [13] Cat: icon | Box: (129, 1231, 184, 1296)
#  → Caption: a baseball player is about to throw the ball [BLIP]
# [14] Cat: icon | Box: (569, 1321, 614, 1368)
#  → Caption: a black and white logo with the letter d on it [BLIP]
# [15] Cat: icon | Box: (954, 1321, 1005, 1370)
#  → Caption: a blue background with a white outline of two books in the center [BLIP]
# [16] Cat: icon | Box: (1344, 1320, 1392, 1371)
#  → Caption: a black and white photo of a person with their hands in the air [BLIP]
# [17] Cat: icon | Box: (1732, 1320, 1780, 1370)
#  → Caption: a black and white logo with the letter d on it [BLIP]
# [18] Cat: icon | Box: (2508, 1324, 2558, 1369)
#  → Caption: a black and white logo with the word ' s on it [BLIP]
# [19] Cat: icon | Box: (2354, 1027, 2401, 1076)
#  → Caption: a black and white image of a map pointer [BLIP]
# [20] Cat: icon | Box: (2552, 1008, 2637, 1094)
#  → Caption: a black square button with a white arrow on it [BLIP]
# [21] Cat: icon | Box: (2637, 1008, 2726, 1094)
#  → Caption: a black square button with a white arrow on it [BLIP]
# [22] Cat: icon | Box: (2790, 1231, 2858, 1298)
#  → Caption: a brown background with a white arrow on it [BLIP]
# [23] Cat: icon | Box: (1395, 1537, 1436, 1580)
#  → Caption: a red circle with the letter c on it [BLIP]
# [24] Cat: icon | Box: (1395, 1599, 1439, 1645)
#  → Caption: a blue square icon on a white background [BLIP]
# [25] Cat: icon | Box: (2151, 1523, 2197, 1569)
#  → Caption: a white background with a blue, red and yellow logo [BLIP]
# [26] Cat: icon | Box: (2332, 1525, 2372, 1563)
#  → Caption: a black and white image of a tick on a white background [BLIP]
# [27] Cat: icon | Box: (2646, 1524, 2686, 1563)
#  → Caption: a black and white image of three circles [BLIP]
# [28] Cat: icon | Box: (2841, 1606, 2899, 1664)
#  → Caption: a brown background with white circles on it [BLIP]
#
# ===== Screenshot 2025-06-09 at 5.28.11 PM.png =====
# [1] Cat: icon | Box: (601, 165, 649, 211)
#  → Caption: a white cross on a black background [BLIP]
# [2] Cat: icon | Box: (85, 1399, 129, 1441)
#  → Caption: a black and white logo [BLIP]
# [3] Cat: icon | Box: (1013, 512, 1124, 621)
#  → Caption: a green circle with an arrow in the middle of it [BLIP]
# [4] Cat: icon | Box: (1176, 699, 1215, 744)
#  → Caption: a black and red logo with the number 19 on it [BLIP]
# [5] Cat: icon | Box: (1958, 699, 2000, 745)
#  → Caption: a black and red logo with the number 19 on it [BLIP]
# [6] Cat: icon | Box: (2826, 502, 2896, 574)
#  → Caption: a black circle with a white arrow in the middle [BLIP]
# [7] Cat: icon | Box: (304, 34, 366, 94)
#  → Caption: a black background with a white circle in the middle [BLIP]
# [8] Cat: icon | Box: (53, 29, 122, 97)
#  → Caption: the logo for spotify [BLIP]
# [9] Cat: icon | Box: (173, 13, 274, 115)
#  → Caption: a black circle with a white house in the middle [BLIP]
# [10] Cat: icon | Box: (1151, 34, 1210, 94)
#  → Caption: a black and white logo on a black background [BLIP]
# [11] Cat: icon | Box: (2322, 43, 2363, 85)
#  → Caption: a black and white photo of a clock [BLIP]
#
# ===== Screenshot 2025-06-10 at 1.40.42 PM.png =====
# [1] Cat: icon | Box: (1672, 1592, 1728, 1650)
#  → Caption: the north face men ' s fine t shirt [BLIP]
# [2] Cat: icon | Box: (91, 720, 180, 809)
#  → Caption: a white button with a black arrow on it [BLIP]
# [3] Cat: icon | Box: (2761, 720, 2847, 806)
#  → Caption: a white button with an arrow on it [BLIP]
# [4] Cat: icon | Box: (2644, 31, 2692, 80)
#  → Caption: a black and white image of a question mark [BLIP]
# [5] Cat: icon | Box: (2715, 31, 2765, 79)
#  → Caption: a black and white icon of a globe [BLIP]
# [6] Cat: icon | Box: (2788, 31, 2836, 79)
#  → Caption: a black and white image of a man ' s face [BLIP]
# [7] 카테고리 '' → 캡션 생략
# [8] Cat: icon | Box: (709, 1593, 763, 1646)
#  → Caption: a black and white image of two speech bubbles [BLIP]
# [9] Cat: icon | Box: (1836, 1593, 1892, 1649)
#  → Caption: a blue and white logo on a white background [BLIP]
#
# ===== Screenshot 2025-06-10 at 1.41.30 PM.png =====
# [1] Cat: icon | Box: (2573, 40, 2626, 93)
#  → Caption: a shopping cart icon on a gray background [BLIP]
# [2] Cat: icon | Box: (187, 9, 302, 125)
#  → Caption: the bmw logo on a black background [BLIP]
# [3] Cat: icon | Box: (557, 45, 602, 90)
#  → Caption: a white check mark on a black background [BLIP]
# [4] Cat: icon | Box: (992, 45, 1034, 87)
#  → Caption: a black background with a white check mark [BLIP]
# [5] Cat: icon | Box: (1237, 46, 1278, 88)
#  → Caption: a black and white photo of a person walking down a street [BLIP]
# [6] Cat: icon | Box: (530, 1524, 671, 1665)
#  → Caption: a black and white icon of a person with a speech bubble [BLIP]
# [7] Cat: icon | Box: (1392, 1517, 1541, 1665)
#  → Caption: a black and white icon of a car [BLIP]
# [8] Cat: icon | Box: (2259, 1513, 2407, 1661)
#  → Caption: a black and white icon of a car [BLIP]
# [9] Cat: icon | Box: (2719, 1169, 2830, 1282)
#  → Caption: a white circle with the word talk on it [BLIP]
# [10] Cat: icon | Box: (2478, 40, 2528, 92)
#  → Caption: a white icon on a gray background [BLIP]
# [11] Cat: icon | Box: (2669, 40, 2720, 92)
#  → Caption: a map with a pin on it [BLIP]
# [12] 카테고리 '' → 캡션 생략
#
# ===== Screenshot 2025-06-10 at 1.45.22 PM.png =====
# [1] Cat: icon | Box: (783, 63, 805, 85)
#  → Caption: a white triangle on a blue background [BLIP]
# [2] Cat: icon | Box: (1544, 63, 1566, 85)
#  → Caption: a white triangle on a blue background [BLIP]
# [3] Cat: icon | Box: (1784, 64, 1806, 85)
#  → Caption: a white triangle on a blue background [BLIP]
# [4] Cat: icon | Box: (2361, 50, 2411, 98)
#  → Caption: a blue background with white text and a magni logo [BLIP]
# [5] Cat: icon | Box: (2432, 46, 2476, 90)
#  → Caption: a padlock on a blue background [BLIP]
# [6] Cat: icon | Box: (913, 1275, 972, 1334)
#  → Caption: the facebook logo [BLIP]
# [7] Cat: icon | Box: (988, 1276, 1044, 1332)
#  → Caption: the twitter logo [BLIP]
# [8] Cat: icon | Box: (1059, 1275, 1116, 1332)
#  → Caption: a blue background with an image of the ins logo [BLIP]
# [9] Cat: icon | Box: (1127, 1270, 1195, 1338)
#  → Caption: YouTube logo [CLIP (0.94)]
# [10] Cat: icon | Box: (1206, 1276, 1263, 1333)
#  → Caption: a blue square icon with two circles in the center [BLIP]
# [11] Cat: icon | Box: (1278, 1275, 1336, 1333)
#  → Caption: LinkedIn logo [CLIP (0.98)]
# [12] Cat: icon | Box: (1350, 1275, 1408, 1333)
#  → Caption: a blue square icon with the letter p on it [BLIP]
# [13] 카테고리 '' → 캡션 생략
# [14] Cat: icon | Box: (2089, 1019, 2131, 1061)
#  → Caption: the google logo [BLIP]
# [15] Cat: icon | Box: (2260, 1025, 2291, 1056)
#  → Caption: a black triangle on a white background [BLIP]
# [16] Cat: icon | Box: (1025, 63, 1047, 85)
#  → Caption: a white triangle on a blue background [BLIP]
# [17] Cat: icon | Box: (1350, 63, 1372, 85)
#  → Caption: a white triangle on a blue background [BLIP]
#
# ✅ 캡션만 저장 완료: /content/drive/MyDrive/gdy/captions_only_fin.txt
